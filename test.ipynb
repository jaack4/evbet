# %%
import get_data

events = get_data.get_events('americanfootball_nfl', '2025-11-19T20:00:00Z')

# %%
odds_params = (
            'americanfootball_nfl',
            events[0]['id'],
            'us',
            'player_field_goals,player_kicking_points,player_pass_attempts',
            'decimal',
            'prizepicks,underdog,fanduel,draftkings,betmgm,espnbet,hardrockbet'
        )

odds_json = get_data.get_event_odds(*odds_params)
print(odds_json)
# Out:
# Remaining requests 447
# Used requests 53
# {'id': '265f0188945bb81ec64751571eb724cb', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2025-11-16T14:30:00Z', 'home_team': 'Miami Dolphins', 'away_team': 'Washington Commanders', 'bookmakers': [{'key': 'draftkings', 'title': 'DraftKings', 'markets': [{'key': 'player_field_goals', 'last_update': '2025-11-14T08:52:54Z', 'outcomes': [{'name': 'Over', 'description': 'Riley Patterson', 'price': 1.88, 'point': 1.5}, {'name': 'Under', 'description': 'Riley Patterson', 'price': 1.88, 'point': 1.5}, {'name': 'Over', 'description': 'Matt Gay', 'price': 2.15, 'point': 1.5}, {'name': 'Under', 'description': 'Matt Gay', 'price': 1.68, 'point': 1.5}]}, {'key': 'player_kicking_points', 'last_update': '2025-11-14T08:52:54Z', 'outcomes': [{'name': 'Over', 'description': 'Riley Patterson', 'price': 2.03, 'point': 7.5}, {'name': 'Under', 'description': 'Riley Patterson', 'price': 1.76, 'point': 7.5}, {'name': 'Over', 'description': 'Matt Gay', 'price': 2.0, 'point': 6.5}, {'name': 'Under', 'description': 'Matt Gay', 'price': 1.78, 'point': 6.5}]}, {'key': 'player_pass_attempts', 'last_update': '2025-11-14T08:52:54Z', 'outcomes': [{'name': 'Over', 'description': 'Tua Tagovailoa', 'price': 1.95, 'point': 31.5}, {'name': 'Under', 'description': 'Tua Tagovailoa', 'price': 1.83, 'point': 31.5}, {'name': 'Over', 'description': 'Marcus Mariota', 'price': 1.93, 'point': 27.5}, {'name': 'Under', 'description': 'Marcus Mariota', 'price': 1.85, 'point': 27.5}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'markets': [{'key': 'player_pass_attempts', 'last_update': '2025-11-14T08:53:02Z', 'outcomes': [{'name': 'Over', 'description': 'Tua Tagovailoa', 'price': 1.88, 'point': 31.5}, {'name': 'Under', 'description': 'Tua Tagovailoa', 'price': 1.88, 'point': 31.5}, {'name': 'Over', 'description': 'Marcus Mariota', 'price': 2.0, 'point': 27.5}, {'name': 'Under', 'description': 'Marcus Mariota', 'price': 1.77, 'point': 27.5}]}]}, {'key': 'espnbet', 'title': 'ESPN BET', 'markets': [{'key': 'player_pass_attempts', 'last_update': '2025-11-14T08:52:27Z', 'outcomes': [{'name': 'Over', 'description': 'Tua Tagovailoa', 'price': 1.83, 'point': 31.5}, {'name': 'Under', 'description': 'Tua Tagovailoa', 'price': 1.91, 'point': 31.5}, {'name': 'Over', 'description': 'Marcus Mariota', 'price': 1.95, 'point': 27.5}, {'name': 'Under', 'description': 'Marcus Mariota', 'price': 1.8, 'point': 27.5}]}]}, {'key': 'hardrockbet', 'title': 'Hard Rock Bet', 'markets': [{'key': 'player_field_goals', 'last_update': '2025-11-14T08:52:54Z', 'outcomes': [{'name': 'Over', 'description': 'Matt Gay', 'price': 2.25, 'point': 1.5}, {'name': 'Under', 'description': 'Matt Gay', 'price': 1.61, 'point': 1.5}, {'name': 'Over', 'description': 'Riley Patterson', 'price': 1.87, 'point': 1.5}, {'name': 'Under', 'description': 'Riley Patterson', 'price': 1.87, 'point': 1.5}]}, {'key': 'player_kicking_points', 'last_update': '2025-11-14T08:52:54Z', 'outcomes': [{'name': 'Over', 'description': 'Matt Gay', 'price': 2.05, 'point': 6.5}, {'name': 'Under', 'description': 'Matt Gay', 'price': 1.74, 'point': 6.5}, {'name': 'Over', 'description': 'Riley Patterson', 'price': 1.95, 'point': 7.5}, {'name': 'Under', 'description': 'Riley Patterson', 'price': 1.77, 'point': 7.5}]}, {'key': 'player_pass_attempts', 'last_update': '2025-11-14T08:52:54Z', 'outcomes': [{'name': 'Over', 'description': 'Tua Tagovailoa', 'price': 1.95, 'point': 31.5}, {'name': 'Under', 'description': 'Tua Tagovailoa', 'price': 1.83, 'point': 31.5}, {'name': 'Over', 'description': 'Marcus Mariota', 'price': 1.8, 'point': 27.5}, {'name': 'Under', 'description': 'Marcus Mariota', 'price': 1.95, 'point': 27.5}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'markets': [{'key': 'player_field_goals', 'last_update': '2025-11-14T08:53:15Z', 'outcomes': [{'name': 'Over', 'description': 'Riley Patterson', 'price': 1.87, 'point': 1.5}, {'name': 'Under', 'description': 'Riley Patterson', 'price': 1.87, 'point': 1.5}, {'name': 'Over', ...

# %%
odds = odds_json

# %%
odds
# Out:
# {'id': '265f0188945bb81ec64751571eb724cb',
#  'sport_key': 'americanfootball_nfl',
#  'sport_title': 'NFL',
#  'commence_time': '2025-11-16T14:30:00Z',
#  'home_team': 'Miami Dolphins',
#  'away_team': 'Washington Commanders',
#  'bookmakers': [{'key': 'draftkings',
#    'title': 'DraftKings',
#    'markets': [{'key': 'player_field_goals',
#      'last_update': '2025-11-14T08:52:54Z',
#      'outcomes': [{'name': 'Over',
#        'description': 'Riley Patterson',
#        'price': 1.88,
#        'point': 1.5},
#       {'name': 'Under',
#        'description': 'Riley Patterson',
#        'price': 1.88,
#        'point': 1.5},
#       {'name': 'Over', 'description': 'Matt Gay', 'price': 2.15, 'point': 1.5},
#       {'name': 'Under',
#        'description': 'Matt Gay',
#        'price': 1.68,
#        'point': 1.5}]},
#     {'key': 'player_kicking_points',
#      'last_update': '2025-11-14T08:52:54Z',
#      'outcomes': [{'name': 'Over',
#        'description': 'Riley Patterson',
#        'price': 2.03,
#        'point': 7.5},
#       {'name': 'Under',
#        'description': 'Riley Patterson',
#        'price': 1.76,
#        'point': 7.5},
#       {'name': 'Over', 'description': 'Matt Gay', 'price': 2.0, 'point': 6.5},
#       {'name': 'Under',
#        'description': 'Matt Gay',
#        'price': 1.78,
#        'point': 6.5}]},
#     {'key': 'player_pass_attempts',
#      'last_update': '2025-11-14T08:52:54Z',
#      'outcomes': [{'name': 'Over',
#        'description': 'Tua Tagovailoa',
#        'price': 1.95,
#        'point': 31.5},
#       {'name': 'Under',
#        'description': 'Tua Tagovailoa',
#        'price': 1.83,
#        'point': 31.5},
#       {'name': 'Over',
#        'description': 'Marcus Mariota',
#        'price': 1.93,
#        'point': 27.5},
#       {'name': 'Under',
#        'description': 'Marcus Mariota',
#        'price': 1.85,
#        'point': 27.5}]}]},
#   {'key': 'fanduel',
#    'title': 'FanDuel',
#    'markets': [{'key': 'player_pass_attempts',
#      'last_update': '2025-11-14T08:53:02Z',
#      'outcomes': [{'name': 'Over',
#        'description': 'Tua Tagovailoa',
#        'price': 1.88,
#        'point': 31.5},
#       {'name': 'Under',
#        'description': 'Tua Tagovailoa',
#        'price': 1.88,
#        'point': 31.5},
#       {'name': 'Over',
#        'description': 'Marcus Mariota',
#        'price': 2.0,
#        'point': 27.5},
#       {'name': 'Under',
#        'description': 'Marcus Mariota',
#        'price': 1.77,
#        'point': 27.5}]}]},
#   {'key': 'espnbet',
#    'title': 'ESPN BET',
#    'markets': [{'key': 'player_pass_attempts',
#      'last_update': '2025-11-14T08:52:27Z',
#      'outcomes': [{'name': 'Over',
#        'description': 'Tua Tagovailoa',
#        'price': 1.83,
#        'point': 31.5},
#       {'name': 'Under',
#        'description': 'Tua Tagovailoa',
#        'price': 1.91,
#        'point': 31.5},
#       {'name': 'Over',
#        'description': 'Marcus Mariota',
#        'price': 1.95,
#        'point': 27.5},
#       {'name': 'Under',
#        'description': 'Marcus Mariota',
#        'price': 1.8,
#        'point': 27.5}]}]},
#   {'key': 'hardrockbet',
#    'title': 'Hard Rock Bet',
#    'markets': [{'key': 'player_field_goals',
#      'last_update': '2025-11-14T08:52:54Z',
#      'outcomes': [{'name': 'Over',
#        'description': 'Matt Gay',
#        'price': 2.25,
#        'point': 1.5},
#       {'name': 'Under',
#        'description': 'Matt Gay',
#        'price': 1.61,
#        'point': 1.5},
#       {'name': 'Over',
#        'description': 'Riley Patterson',
#        'price': 1.87,
#        'point': 1.5},
#       {'name': 'Under',
#        'description': 'Riley Patterson',
#        'price': 1.87,
#        'point': 1.5}]},
#     {'key': 'player_kicking_points',
#      'last_update': '2025-11-14T08:52:54Z',
#      'outcomes': [{'name': 'Over',
#        'description': 'Matt Gay',
#        'price': 2.05,
#        'point': 6.5},
#       {'name': 'Under',
#        'description': 'Matt Gay',
#        'price': 1.74,
#        'point': 6.5},
#       {'name': 'Over',
#        'description': 'Riley Patterson',
#        'price': 1.95,
#        'point': 7.5},
#       {'name': 'Under',
#        'description': 'Riley Patterson',
#        'price': 1.77,
#        'point': 7.5}]},
#     {'key': 'player_pass_attempts',
#      'last_update': '2025-11-14T08:52:54Z',
#      'outcomes': [{'name': 'Over',
#        'description': 'Tua Tagovailoa',
#        'price': 1.95,
#        'point': 31.5},
#       {'name': 'Under',
#        'description': 'Tua Tagovailoa',
#        'price': 1.83,
#        'point': 31.5},
#       {'name': 'Over',
#        'description': 'Marcus Mariota',
#        'price': 1.8,
#        'point': 27.5},
#       {'name': 'Under',
#        'description': 'Marcus Mariota',
#        'price': 1.95,
#        'point': 27.5}]}]},
#   {'key': 'betmgm',
#    'title': 'BetMGM',
#    'markets': [{'key': 'player_field_goals',
#      'last_update': '2025-11-14T08:53:15Z',
#      'outcomes': [{'name': 'Over',
#        'description': 'Riley Patterson',
#        'price': 1.87,
#        'point': 1.5},
#       {'name': 'Under',
#        'description': 'Riley Patterson',
#        'price': 1.87,
#        'point': 1.5},
#       {'name': 'Over', 'description': 'Matt Gay', 'price': 2.25, 'point': 1.5},
#       {'name': 'Under',
#        'description': 'Matt Gay',
#        'price': 1.61,
#        'point': 1.5}]},
#     {'key': 'player_kicking_points',
#      'last_update': '2025-11-14T08:53:15Z',
#      'outcomes': [{'name': 'Over',
#        'description': 'Riley Patterson',
#        'price': 1.95,
#        'point': 7.5},
#       {'name': 'Under',
#        'description': 'Riley Patterson',
#        'price': 1.77,
#        'point': 7.5},
#       {'name': 'Over', 'description': 'Matt Gay', 'price': 2.05, 'point': 6.5},
#       {'name': 'Under',
#        'description': 'Matt Gay',
#        'price': 1.71,
#        'point': 6.5}]},
#     {'key': 'player_pass_attempts',
#      'last_update': '2025-11-14T08:53:15Z',
#      'outcomes': [{'name': 'Over',
#        'description': 'Marcus Mariota',
#        'price': 1.77,
#        'point': 27.5},
#       {'name': 'Under',
#        'description': 'Marcus Mariota',
#        'price': 1.95,
#        'point': 27.5},
#       {'name': 'Over',
#        'description': 'Tua Tagovailoa',
#        'price': 1.91,
#        'point': 31.5},
#       {'name': 'Under',
#        'description': 'Tua Tagovailoa',
#        'price': 1.83,
#        'point': 31.5}]}]},
#   {'key': 'prizepicks',
#    'title': 'PrizePicks',
#    'markets': [{'key': 'player_field_goals',
#      'last_update': '2025-11-14T08:51:13Z',
#      'outcomes': [{'name': 'Over',
#        'description': 'Riley Patterson',
#        'price': 1.73,
#        'point': 1.5},
#       {'name': 'Under',
#        'description': 'Riley Patterson',
#        'price': 1.73,
#        'point': 1.5}]},
#     {'key': 'player_kicking_points',
#      'last_update': '2025-11-14T08:51:13Z',
#      'outcomes': [{'name': 'Over',
#        'description': 'Riley Patterson',
#        'price': 1.73,
#        'point': 7.5},
#       {'name': 'Under',
#        'description': 'Riley Patterson',
#        'price': 1.73,
#        'point': 7.5}]},
#     {'key': 'player_pass_attempts',
#      'last_update': '2025-11-14T08:51:13Z',
#      'outcomes': [{'name': 'Over',
#        'description': 'Tua Tagovailoa',
#        'price': 1.73,
#        'point': 31.0},
#       {'name': 'Under',
#        'description': 'Tua Tagovailoa',
#        'price': 1.73,
#        'point': 31.0},
#       {'name': 'Over',
#        'description': 'Marcus Mariota',
#        'price': 1.73,
#        'point': 27.5},
#       {'name': 'Under',
#        'description': 'Marcus Mariota',
#        'price': 1.73,
#        'point': 27.5}]}]},
#   {'key': 'underdog',
#    'title': 'Underdog',
#    'markets': [{'key': 'player_field_goals',
#      'last_update': '2025-11-14T08:53:34Z',
#      'outcomes': [{'name': 'Over',
#        'description': 'Riley Patterson',
#        'price': 1.73,
#        'point': 1.5},
#       {'name': 'Under',
#        'description': 'Riley Patterson',
#        'price': 1.73,
#        'point': 1.5}]},
#     {'key': 'player_kicking_points',
#      'last_update': '2025-11-14T08:53:34Z',
#      'outcomes': [{'name': 'Over',
#        'description': 'Riley Patterson',
#        'price': 1.73,
#        'point': 7.5},
#       {'name': 'Under',
#        'description': 'Riley Patterson',
#        'price': 1.73,
#        'point': 7.5}]},
#     {'key': 'player_pass_attempts',
#      'last_update': '2025-11-14T08:53:34Z',
#      'outcomes': [{'name': 'Over',
#        'description': 'Tua Tagovailoa',
#        'price': 1.73,
#        'point': 31.5},
#       {'name': 'Under',
#        'description': 'Tua Tagovailoa',
#        'price': 1.73,
#        'point': 31.5},
#       {'name': 'Over',
#        'description': 'Marcus Mariota',
#        'price': 1.73,
#        'point': 27.5},
#       {'name': 'Under',
#        'description': 'Marcus Mariota',
#        'price': 1.73,
#        'point': 27.5}]}]}]}
