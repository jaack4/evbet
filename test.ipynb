# %%
import get_data

events = get_data.get_events('americanfootball_nfl', '2025-11-26T20:00:00Z')

# %%
odds_params = (
            'americanfootball_nfl',
            events[0]['id'],
            'us',
            'player_field_goals,player_kicking_points,player_pass_attempts',
            'decimal',
            'prizepicks,underdog,fanduel,draftkings,betmgm,espnbet,hardrockbet'
        )

odds_json = get_data.get_event_odds(*odds_params)
print(odds_json)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 10
#       1 odds_params = (
#       2             'americanfootball_nfl',
#       3             events[0]['id'],
#    (...)      7             'prizepicks,underdog,fanduel,draftkings,betmgm,espnbet,hardrockbet'
#       8         )
# ---> 10 odds_json = get_data.get_event_odds(*odds_params)
#      11 print(odds_json)
#
# AttributeError: module 'get_data' has no attribute 'get_event_odds'

# %%
odds = odds_json

# %%
odds

# %%
print(odds.keys())
for x in odds.values():
    print(x)

# %%
book = odds['bookmakers']
print(type(book))
len(book)
for x in book:
    print(x)

# %%
book[0]["markets"][0].keys()

# %%
import get_data
game = get_data.main()
# Out:
# [{'id': 'cd2e0964817c30ad3f5144ea49b55f2b', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2025-11-21T01:15:00Z', 'home_team': 'Houston Texans', 'away_team': 'Buffalo Bills'}, {'id': '7159d60c7a31c7d593167637723d7663', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2025-11-23T18:00:00Z', 'home_team': 'Baltimore Ravens', 'away_team': 'New York Jets'}, {'id': 'c8913b70b63ae247f23a4e1dec08c668', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2025-11-23T18:00:00Z', 'home_team': 'Chicago Bears', 'away_team': 'Pittsburgh Steelers'}, {'id': '1a8f3d70399a5cad83c95196795ed77b', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2025-11-23T18:00:00Z', 'home_team': 'Cincinnati Bengals', 'away_team': 'New England Patriots'}, {'id': '535bbe97d4e56494b039ade88459c338', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2025-11-23T18:00:00Z', 'home_team': 'Detroit Lions', 'away_team': 'New York Giants'}, {'id': '91019a528f43cd28965fdc68a3f3ef85', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2025-11-23T18:00:00Z', 'home_team': 'Green Bay Packers', 'away_team': 'Minnesota Vikings'}, {'id': '8b39d8dc550ced94f9faa91878ebf6b6', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2025-11-23T18:00:00Z', 'home_team': 'Kansas City Chiefs', 'away_team': 'Indianapolis Colts'}, {'id': '0ff4e68cf39cc57ca7cf1276e4a44d2f', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2025-11-23T18:00:00Z', 'home_team': 'Tennessee Titans', 'away_team': 'Seattle Seahawks'}, {'id': 'e32e0030899c06fdf2c74745ca27d85a', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2025-11-23T21:05:00Z', 'home_team': 'Arizona Cardinals', 'away_team': 'Jacksonville Jaguars'}, {'id': '27f50ddbc4c3fbad10398c5187a28dc7', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2025-11-23T21:05:00Z', 'home_team': 'Las Vegas Raiders', 'away_team': 'Cleveland Browns'}, {'id': '8c2d6a56aa63f42227f18a18fc3d2146', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2025-11-23T21:25:00Z', 'home_team': 'New Orleans Saints', 'away_team': 'Atlanta Falcons'}, {'id': '4553ba763cb3cfcfc33fd62672a2057f', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2025-11-23T21:25:00Z', 'home_team': 'Dallas Cowboys', 'away_team': 'Philadelphia Eagles'}, {'id': '9e7119f5a24471c39145663b84f100b2', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2025-11-24T01:20:00Z', 'home_team': 'Los Angeles Rams', 'away_team': 'Tampa Bay Buccaneers'}, {'id': '90391be251d876bb41d36978a43c7ac2', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2025-11-25T01:15:00Z', 'home_team': 'San Francisco 49ers', 'away_team': 'Carolina Panthers'}]
# Remaining requests 433
# Used requests 67
# Game(id=cd2e0964817c30ad3f5144ea49b55f2b, sport_key=americanfootball_nfl, sport_title=NFL, commence_time=2025-11-21T01:15:00Z, home_team=Houston Texans, away_team=Buffalo Bills, bookmakers=prizepicks,underdog,fanduel,draftkings,betmgm,espnbet,hardrockbet, markets=player_field_goals,player_kicking_points)

# %%
game.odds_df
# Out:
#      bookmaker                 market            player outcome  line  price  \
# 0       betmgm     player_field_goals  Ka'imi Fairbairn    Over   1.5   1.71
# 1       betmgm     player_field_goals  Ka'imi Fairbairn   Under   1.5   2.05
# 2       betmgm     player_field_goals       Matt Prater    Over   1.5   1.95
# 3       betmgm     player_field_goals       Matt Prater   Under   1.5   1.80
# 4       betmgm  player_kicking_points  Ka'imi Fairbairn    Over   6.5   1.69
# 5       betmgm  player_kicking_points  Ka'imi Fairbairn   Under   6.5   2.10
# 6       betmgm  player_kicking_points       Matt Prater    Over   7.5   2.10
# 7       betmgm  player_kicking_points       Matt Prater   Under   7.5   1.69
# 8     underdog     player_field_goals       Matt Prater    Over   1.5   1.73
# 9     underdog     player_field_goals       Matt Prater   Under   1.5   1.73
# 10  prizepicks     player_field_goals       Matt Prater    Over   1.5   1.73
# 11  prizepicks     player_field_goals       Matt Prater   Under   1.5   1.73
#
#              last_update
# 0   2025-11-19T00:43:13Z
# 1   2025-11-19T00:43:13Z
# 2   2025-11-19T00:43:13Z
# 3   2025-11-19T00:43:13Z
# 4   2025-11-19T00:43:13Z
# 5   2025-11-19T00:43:13Z
# 6   2025-11-19T00:43:13Z
# 7   2025-11-19T00:43:13Z
# 8   2025-11-19T00:43:37Z
# 9   2025-11-19T00:43:37Z
# 10  2025-11-19T00:43:28Z
# 11  2025-11-19T00:43:28Z
